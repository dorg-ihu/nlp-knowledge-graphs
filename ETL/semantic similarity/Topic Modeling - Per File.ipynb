# %% [markdown]
# ## BERTopic
# BERTopic is a topic modeling technique that leverages 🤗 transformers and a custom class-based TF-IDF to create dense clusters allowing for easily interpretable topics whilst keeping important words in the topic descriptions.

# %% [markdown]
# # Enabling the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down

# %% [markdown]
# # **Installing BERTopic**
#
# We start by installing BERTopic from PyPi:

# %%
# %%capture
# !pip install bertopic

# %% [markdown]
# ## Restart the Notebook
# After installing BERTopic, some packages that were already loaded were updated and in order to correctly use them, we should now restart the notebook.
#
# From the Menu:
#
# Runtime → Restart Runtime

# %% [markdown]
# #Connect to sharepoint

# %%
# !pip install office365
# !pip install Office365-REST-Python-Client
# Out:
# Collecting office365
#   Downloading office365-0.3.15-py3-none-any.whl (32 kB)
# Collecting azure-storage-blob (from office365)
#   Downloading azure_storage_blob-12.17.0-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 11.8 MB/s eta 0:00:00
# Collecting O365 (from office365)
#   Downloading O365-2.0.27-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.2/164.2 kB 19.8 MB/s eta 0:00:00
# Collecting pymiscutils (from office365)
#   Downloading pymiscutils-0.3.14-py3-none-any.whl (14 kB)
# Collecting pathmagic (from office365)
#   Downloading pathmagic-0.3.14-py3-none-any.whl (21 kB)
# Collecting pyiotools (from office365)
#   Downloading pyiotools-0.3.18-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 4.7 MB/s eta 0:00:00
# Collecting pysubtypes (from office365)
#   Downloading pysubtypes-0.3.18-py3-none-any.whl (31 kB)
# Collecting maybe-else (from office365)
#   Downloading maybe_else-0.2.1-py3-none-any.whl (5.5 kB)
# Collecting azure-core<2.0.0,>=1.28.0 (from azure-storage-blob->office365)
#   Downloading azure_core-1.28.0-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.4/185.4 kB 19.7 MB/s eta 0:00:00
# Collecting cryptography>=2.1.4 (from azure-storage-blob->office365)
#   Downloading cryptography-41.0.2-cp37-abi3-manylinux_2_28_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 70.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob->office365) (4.7.1)
# Collecting isodate>=0.6.1 (from azure-storage-blob->office365)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from O365->office365) (2.27.1)
# Requirement already satisfied: requests-oauthlib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from O365->office365) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from O365->office365) (2.8.2)
# Requirement already satisfied: pytz>=2018.5 in /usr/local/lib/python3.10/dist-packages (from O365->office365) (2022.7.1)
# Collecting tzlocal<5.0,>=4.0 (from O365->office365)
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: beautifulsoup4>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from O365->office365) (4.11.2)
# Collecting stringcase>=1.2.0 (from O365->office365)
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pathmagic->office365) (1.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from pathmagic->office365) (8.4.0)
# Collecting PyPDF2 (from pathmagic->office365)
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pathmagic->office365) (1.4.4)
# Collecting bs4 (from pathmagic->office365)
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dill (from pathmagic->office365)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.1 MB/s eta 0:00:00
# Collecting python-docx (from pathmagic->office365)
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 108.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (from pathmagic->office365) (1.0.3)
# Collecting pydub (from pathmagic->office365)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from pathmagic->office365) (1.8.2)
# Collecting simplejson (from pathmagic->office365)
#   Downloading simplejson-3.19.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.2 MB/s eta 0:00:00
# Collecting APScheduler (from pyiotools->office365)
#   Downloading APScheduler-3.10.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 8.2 MB/s eta 0:00:00
# Collecting cursor (from pyiotools->office365)
#   Downloading cursor-1.3.5.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting readchar (from pyiotools->office365)
#   Downloading readchar-4.0.5-py3-none-any.whl (8.5 kB)
# Collecting colorama (from pyiotools->office365)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting infi.systray (from pyiotools->office365)
#   Downloading infi.systray-0.1.12-py3-none-any.whl (9.2 kB)
# Collecting PyQt5 (from pyiotools->office365)
#   Downloading PyQt5-5.15.9-cp37-abi3-manylinux_2_17_x86_64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 98.0 MB/s eta 0:00:00
# Collecting typepy (from pyiotools->office365)
#   Downloading typepy-1.3.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pymiscutils->office365) (1.22.4)
# Collecting gender-guesser (from pymiscutils->office365)
#   Downloading gender_guesser-0.4.0-py2.py3-none-any.whl (379 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.3/379.3 kB 43.0 MB/s eta 0:00:00
# Collecting pyinstrument (from pymiscutils->office365)
#   Downloading pyinstrument-4.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.2/105.2 kB 15.3 MB/s eta 0:00:00
# Collecting aenum (from pysubtypes->office365)
#   Downloading aenum-3.1.15-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 18.3 MB/s eta 0:00:00
# Collecting case-conversion (from pysubtypes->office365)
#   Downloading case_conversion-2.1.0.tar.gz (4.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting colour (from pysubtypes->office365)
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting clipboard (from pysubtypes->office365)
#   Downloading clipboard-0.0.4.tar.gz (1.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting html-text (from pysubtypes->office365)
#   Downloading html_text-0.5.2-py2.py3-none-any.whl (7.5 kB)
# Collecting fuzzywuzzy (from pysubtypes->office365)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from pysubtypes->office365) (6.0.5)
# Collecting parsedatetime (from pysubtypes->office365)
#   Downloading parsedatetime-2.6-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 5.7 MB/s eta 0:00:00
# Collecting prettierfier (from pysubtypes->office365)
#   Downloading prettierfier-1.0.3-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from pysubtypes->office365) (2022.10.31)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pysubtypes->office365) (0.8.10)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pysubtypes->office365) (1.26.16)
# Collecting xlsxwriter (from pysubtypes->office365)
#   Downloading XlsxWriter-3.1.2-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 16.1 MB/s eta 0:00:00
# Collecting msoffcrypto-tool (from pysubtypes->office365)
#   Downloading msoffcrypto_tool-5.0.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob->office365) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.0.0->O365->office365) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob->office365) (1.15.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.0->O365->office365) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.0->O365->office365) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.0->O365->office365) (3.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=1.2.0->O365->office365) (3.2.2)
# Collecting pytz-deprecation-shim (from tzlocal<5.0,>=4.0->O365->office365)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools>=0.7 in /usr/local/lib/python3.10/dist-packages (from APScheduler->pyiotools->office365) (67.7.2)
# Collecting pyperclip>=1.3 (from clipboard->pysubtypes->office365)
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from html-text->pysubtypes->office365) (4.9.3)
# Requirement already satisfied: pydantic<2,>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect->pysubtypes->office365) (1.10.11)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->pathmagic->office365) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->pathmagic->office365) (4.65.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->pathmagic->office365) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy->pathmagic->office365) (2.25.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->pathmagic->office365) (0.4.8)
# Collecting olefile>=0.46 (from msoffcrypto-tool->pysubtypes->office365)
#   Downloading olefile-0.46.zip (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting PyQt5-sip<13,>=12.11 (from PyQt5->pyiotools->office365)
#   Downloading PyQt5_sip-12.12.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (360 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.5/360.5 kB 39.2 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2 (from PyQt5->pyiotools->office365)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 23.4 MB/s eta 0:00:00
# Collecting mbstrdecoder<2,>=1.0.0 (from typepy->pyiotools->office365)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob->office365) (2.21)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->typepy->pyiotools->office365) (4.0.0)
# Collecting tzdata (from pytz-deprecation-shim->tzlocal<5.0,>=4.0->O365->office365)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 34.0 MB/s eta 0:00:00
# Building wheels for collected packages: stringcase, bs4, case-conversion, clipboard, cursor, python-docx, olefile, pyperclip
#   Building wheel for stringcase (setup.py) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3569 sha256=2ef1e7edcc875944bb2fc243a9d763866bce89ec2c13e943f5b2164875e90d78
#   Stored in directory: /root/.cache/pip/wheels/31/ba/22/1a2d952a9ce8aa86e42fda41e2c87fdaf20e238c88bf8df013
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=07c64d70b06902fcfcb2a6b56ba6bed3ba64401aed50a46aae19b6e40e15cbb5
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
#   Building wheel for case-conversion (setup.py) ... done
#   Created wheel for case-conversion: filename=case_conversion-2.1.0-py3-none-any.whl size=5343 sha256=c75357a7748843ef1b63f78fd3a2d7e9c8868967cc996e7ef82fc331af9f6556
#   Stored in directory: /root/.cache/pip/wheels/05/9c/c6/74b44af215cbc418a961c4de5002ecd5a719b57d5ceb341caa
#   Building wheel for clipboard (setup.py) ... done
#   Created wheel for clipboard: filename=clipboard-0.0.4-py3-none-any.whl size=1849 sha256=66c9337344403d68b418cfc121a228ce9ecb3ec3815cd6d615007d0787a0cce0
#   Stored in directory: /root/.cache/pip/wheels/a9/16/29/0b45762bf14ad4ba5495cd4ce66c7e326ecb0d5f1edeb7c94d
#   Building wheel for cursor (setup.py) ... done
#   Created wheel for cursor: filename=cursor-1.3.5-py3-none-any.whl size=15821 sha256=334a8469c228590450bd36740f3149a51580e0a95899c0c17c0269cecb1e2d22
#   Stored in directory: /root/.cache/pip/wheels/bb/08/7f/46a8be2d2406ef8f31f519626da634ff35ad543bf5b2a77d95
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184491 sha256=328d7a9fbbbb83b5b64995f633cb2ceab0d021f7a18c01b1eba1e1901e21d907
#   Stored in directory: /root/.cache/pip/wheels/80/27/06/837436d4c3bd989b957a91679966f207bfd71d358d63a8194d
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35417 sha256=9a8c644d192e435a1adeb9cd147520b8aefc95df0e47573111b4f1365a31794a
#   Stored in directory: /root/.cache/pip/wheels/02/39/c0/9eb1f7a42b4b38f6f333b6314d4ed11c46f12a0f7b78194f0d
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11124 sha256=b957f36e394a02871d9c94453aff22701a2bc1447be2e30309f2690af819c05f
#   Stored in directory: /root/.cache/pip/wheels/04/24/fe/140a94a7f1036003ede94579e6b4227fe96c840c6f4dcbe307
# Successfully built stringcase bs4 case-conversion clipboard cursor python-docx olefile pyperclip
# Installing collected packages: stringcase, PyQt5-Qt5, pyperclip, pydub, prettierfier, parsedatetime, maybe-else, gender-guesser, fuzzywuzzy, cursor, colour, aenum, xlsxwriter, tzdata, simplejson, readchar, python-docx, PyQt5-sip, PyPDF2, pyinstrument, olefile, mbstrdecoder, isodate, infi.systray, html-text, dill, colorama, clipboard, case-conversion, typepy, pytz-deprecation-shim, PyQt5, cryptography, bs4, azure-core, tzlocal, msoffcrypto-tool, azure-storage-blob, pysubtypes, O365, APScheduler, pathmagic, pymiscutils, pyiotools, office365
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 5.0.1
#     Uninstalling tzlocal-5.0.1:
#       Successfully uninstalled tzlocal-5.0.1
# Successfully installed APScheduler-3.10.1 O365-2.0.27 PyPDF2-3.0.1 PyQt5-5.15.9 PyQt5-Qt5-5.15.2 PyQt5-sip-12.12.1 aenum-3.1.15 azure-core-1.28.0 azure-storage-blob-12.17.0 bs4-0.0.1 case-conversion-2.1.0 clipboard-0.0.4 colorama-0.4.6 colour-0.1.5 cryptography-41.0.2 cursor-1.3.5 dill-0.3.6 fuzzywuzzy-0.18.0 gender-guesser-0.4.0 html-text-0.5.2 infi.systray-0.1.12 isodate-0.6.1 maybe-else-0.2.1 mbstrdecoder-1.1.3 msoffcrypto-tool-5.0.1 office365-0.3.15 olefile-0.46 parsedatetime-2.6 pathmagic-0.3.14 prettierfier-1.0.3 pydub-0.25.1 pyinstrument-4.5.0 pyiotools-0.3.18 pymiscutils-0.3.14 pyperclip-1.8.2 pysubtypes-0.3.18 python-docx-0.8.11 pytz-deprecation-shim-0.1.0.post0 readchar-4.0.5 simplejson-3.19.1 stringcase-1.2.0 typepy-1.3.1 tzdata-2023.3 tzlocal-4.3.1 xlsxwriter-3.1.2
# Collecting Office365-REST-Python-Client
#   Downloading Office365_REST_Python_Client-2.4.2-py3-none-any.whl (909 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 909.2/909.2 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from Office365-REST-Python-Client) (2.27.1)
# Collecting msal (from Office365-REST-Python-Client)
#   Downloading msal-1.22.0-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from Office365-REST-Python-Client) (2022.7.1)
# Collecting PyJWT[crypto]<3,>=1.0.0 (from msal->Office365-REST-Python-Client)
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: cryptography<43,>=0.6 in /usr/local/lib/python3.10/dist-packages (from msal->Office365-REST-Python-Client) (41.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->Office365-REST-Python-Client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->Office365-REST-Python-Client) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->Office365-REST-Python-Client) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->Office365-REST-Python-Client) (3.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<43,>=0.6->msal->Office365-REST-Python-Client) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<43,>=0.6->msal->Office365-REST-Python-Client) (2.21)
# Installing collected packages: PyJWT, msal, Office365-REST-Python-Client
# Successfully installed Office365-REST-Python-Client-2.4.2 PyJWT-2.7.0 msal-1.22.0

# %%
from office365.runtime.auth.authentication_context import AuthenticationContext
from office365.sharepoint.client_context import ClientContext
from office365.runtime.auth.client_credential import ClientCredential
from office365.sharepoint.files.file import File

####inputs########
# This will be the URL that points to your sharepoint site.
# Make sure you change only the parts of the link that start with "Your"
url_shrpt = 'https://ihuedu.sharepoint.com/sites/EDYTEProject2023/'
username_shrpt = '###############'
password_shrpt = '###############'
folder_files_url_shrpt = '/sites/EDYTEProject2023/Shared%20Documents/General/wp5_data/raw_Data/'
folder_analysis_url_shrpt = '/sites/EDYTEProject2023/Shared%20Documents/General/wp5_data/analysis_exports/'

# %%
###Authentication###For authenticating into your sharepoint site###
ctx_auth = AuthenticationContext(url_shrpt)
if ctx_auth.acquire_token_for_user(username_shrpt, password_shrpt):
  ctx = ClientContext(url_shrpt, ctx_auth)
  web = ctx.web
  ctx.load(web)
  ctx.execute_query()
  print('Authenticated into sharepoint as: ',web.properties['Title'])

else:
  print(ctx_auth.get_last_error())
############################
# Out:
# Authenticated into sharepoint as:  EDYTE Project 2023

# %%
####Function for extracting the file names of a folder in sharepoint###
###If you want to extract the folder names instead of file names, you have to change "sub_folders = folder.files" to "sub_folders = folder.folders" in the below function

global print_folder_contents
def print_folder_contents(ctx, folder_url):
    try:

        folder = ctx.web.get_folder_by_server_relative_url(folder_url)
        fold_names = []
        sub_folders = folder.files #Replace files with folders for getting list of folders
        ctx.load(sub_folders)
        ctx.execute_query()

        for s_folder in sub_folders:

            fold_names.append(s_folder.properties["Name"])

        return fold_names

    except Exception as e:
        print('Problem printing out library contents: ', e)
######################################################

# Call the function by giving your folder URL as input
filelist_shrpt=print_folder_contents(ctx,folder_files_url_shrpt)
#Print the list of files present in the folder
print(filelist_shrpt)
# Out:
# ['process-provision-digital-locations.csv', 'process-steps-digital.csv', 'process-steps.csv', 'process-evidences-cost.csv', 'process.csv', 'process-rules.csv', 'process-conditions.csv', 'process-evidences.csv']

# %% [markdown]
# # Import Data

# %%
import pandas as pd
import csv
import numpy as np
import io
import os
import tempfile

# %%
def process_csv_file(file_name, column_names):
    file_url= folder_files_url_shrpt+file_name
    response = File.open_binary(ctx, file_url)  # Assuming File is imported and ctx is defined
    df = pd.read_csv(io.BytesIO(response.content))
    df = df.dropna(subset=column_names)
    data = df[column_names]
    docs = df[column_names[-1]].values.tolist()
    return df, docs

# %%
#process steps
process_steps, process_steps_docs = process_csv_file( "process-steps.csv", ["process_id", "ihu_unique_step_id", "step_title"])

#process steps digital
process_digital_steps, process_digtial_steps_docs = process_csv_file( "process-steps-digital.csv", ["process_id", "ihu_unique_step_digital_id", "step_digital_title"])

#process title
process_title, process_title_docs = process_csv_file( "process.csv", ["id", "title_el"])

#process evidences
process_evidences, process_evidences_docs = process_csv_file( "process-evidences.csv", ["process_id", "ihu_unique_evidence_id", "evidence_description"])

#process conditions
process_conditions, process_conditions_docs = process_csv_file( "process-conditions.csv", ["process_id", "ihu_unique_condition_id", "conditions_name"])

# %% [markdown]
# # **Topic Modeling**

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Stop Words for Count Vectorizer

# %%
# get Greek stop_words
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
greek_stopwords = stopwords.words('greek')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
new_words = ['της', 'τη', 'του', 'από']

for word in new_words:
  greek_stopwords.append(word)

# %% [markdown]
# ### Topic

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer # Embeddings
from umap import UMAP #Dimensionality reduction
from hdbscan import HDBSCAN #clustering
from sklearn.feature_extraction.text import CountVectorizer # CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from transformers.pipelines import pipeline

# %%
def create_topic_model(n_neighbors, n_components, min_dist, min_cluster_size, documents):
    # Define the embedding model
    embedding_model = SentenceTransformer("paraphrase-multilingual-mpnet-base-v2")

    # Define the UMAP model
    umap_model = UMAP(n_neighbors=n_neighbors, n_components=n_components, min_dist=min_dist, metric='cosine') #increasing n_neighbors in general larger clusters | n_components - in which dimension. Too small loss of info, too high performance | min_dist how far the points should be in low dimensional

    # Define the HDBSCAN model
    hdbscan_model = HDBSCAN(min_cluster_size=min_cluster_size, metric='euclidean', cluster_selection_method='eom') #min_cluster_size, increasing -> fewer clusters | cluster_selection_method also the "leaf" method available (smaller clusters)

    # Define the vectorizer model
    vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words=greek_stopwords) #ngram_range combination of words

    # Define the class-TFIDF transformer
    ctfidf_model = ClassTfidfTransformer(bm25_weighting=True)

    # Create the topic model
    topic_model = BERTopic(embedding_model=embedding_model, umap_model=umap_model, hdbscan_model=hdbscan_model,
                           vectorizer_model=vectorizer_model, ctfidf_model=ctfidf_model)

    # Fit the topic model to the process steps documents
    topics, probs = topic_model.fit_transform(documents)

    return topic_model, topics, probs

# %%
def reduce_outliers(documents, topic_model, topics, threshold):
    # Define the vectorizer model
    vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words=greek_stopwords) #ngram_range combination of words

    # Define the class-TFIDF transformer
    ctfidf_model = ClassTfidfTransformer(bm25_weighting=True)

    # Reduce outliers using embeddings
    new_topics = topic_model.reduce_outliers(documents, topics, strategy="embeddings", threshold=threshold)

    # Update topics
    topic_model.update_topics(documents, topics=new_topics, vectorizer_model=vectorizer_model, ctfidf_model=ctfidf_model)

# %%
def merge_topics(documents, topic_model, list):
    # Define the vectorizer model
    vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words=greek_stopwords) #ngram_range combination of words

    # Define the class-TFIDF transformer
    ctfidf_model = ClassTfidfTransformer(bm25_weighting=True)

    # Merge the specified topics
    merged_topics = topic_model.merge_topics(documents, topics_to_merge)

    # Update the topics with the merged topics
    topic_model.update_topics(documents, topics=merged_topics, vectorizer_model=vectorizer_model,
                              ctfidf_model=ctfidf_model)

# %% [markdown]
# # Training

# %% [markdown]
# ##Steps

# %%
steps_topic_model, steps_topics, steps_probs = create_topic_model(100, 10, 0.5, 25, process_steps_docs)
freq = steps_topic_model.get_topic_info(); freq.head(1)
# Out:
#    Topic  Count                                    Name  \
# 0     -1  10284  -1_στοιχείων_φακέλου_κοινοποίηση_φορέα
#
#                                       Representation  \
# 0  [στοιχείων, φακέλου, κοινοποίηση, φορέα, εξέτα...
#
#                                  Representative_Docs
# 0  [Παραλαβή της Αίτησης, Διαβίβαση απόφασης στο ...

# %%
freq["Topic"].nunique()
# Out:
# 163

# %% [markdown]
# -1 refers to all outliers. But this amount is quite high, so we would like to reduce the noise. Closely related items will be assigned in the same topic. And in that topic they would be recognised as unique in the similarity process

# %%
reduce_outliers(process_steps_docs, steps_topic_model, steps_topics, 0.7)
freq = steps_topic_model.get_topic_info(); freq.head(1)
# Out:
#    Topic  Count                              Name  \
# 0     -1   1995  -1_εγγραφή_αγγλικής_μητρώο_μελών
#
#                                       Representation  \
# 0  [εγγραφή, αγγλικής, μητρώο, μελών, γλώσσας, μέ...
#
#                                  Representative_Docs
# 0  [Παραλαβή της Αίτησης, Διαβίβαση απόφασης στο ...

# %% [markdown]
# We reduced a lot the outliers to 10%, which would be good for our semantic analysis.  Finally have a look if we should merge some topics

# %%
steps_topic_model.visualize_hierarchy(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="14b86fd6-af74-4005-855b-191cffca8711" class="plotly-graph-div" style="height:950px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14b86fd6-af74-4005-855b-191cffca8711")) {                    Plotly.newPlot(                        "14b86fd6-af74-4005-855b-191cffca8711",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.800738196611677,0.800738196611677,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9095116445715521,0.9095116445715521,0.800738196611677],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.8879852628765994,0.8879852628765994,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8806302808425153,0.8806302808425153,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9584390996356545,0.9584390996356545,0.8806302808425153],"xaxis":"x","y":[-55.0,-55.0,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9270561831513981,0.9270561831513981,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9612660179037394,0.9612660179037394,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.969124914816185,0.969124914816185,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.9612660179037394,0.9866587268877651,0.9866587268877651,0.969124914816185],"xaxis":"x","y":[-110.0,-110.0,-130.0,-130.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9270561831513981,1.0048123479918099,1.0048123479918099,0.9866587268877651],"xaxis":"x","y":[-90.0,-90.0,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9584390996356545,1.029182475842792,1.029182475842792,1.0048123479918099],"xaxis":"x","y":[-62.5,-62.5,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8879852628765994,1.0498171644085872,1.0498171644085872,1.029182475842792],"xaxis":"x","y":[-40.0,-40.0,-83.75,-83.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9489025912147907,0.9489025912147907,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.9489025912147907,0.9746855380140285,0.9746855380140285,0.0],"xaxis":"x","y":[-170.0,-170.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9898014807445965,0.9898014807445965,0.9746855380140285],"xaxis":"x","y":[-155.0,-155.0,-177.5,-177.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0158424490214069,1.0158424490214069,0.9898014807445965],"xaxis":"x","y":[-145.0,-145.0,-166.25,-166.25],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9075814369029882,0.9075814 ...

# %%
topics_to_merge = [[5,27]]
merge_topics (process_steps_docs, steps_topic_model, topics_to_merge)
freq = steps_topic_model.get_topic_info(); freq.head(3)
# Out:
#    Topic  Count                                               Name  \
# 0     -1   1995                   -1_εγγραφή_αγγλικής_μητρώο_μελών
# 1      0    840       0_άδειας_κατηγορίας_χορήγηση άδειας_εμπορίας
# 2      1    671  1_εκπαίδευσης_εκπαιδευτικών_δευτεροβάθμιας_δευ...
#
#                                       Representation  \
# 0  [εγγραφή, αγγλικής, μητρώο, μελών, γλώσσας, μέ...
# 1  [άδειας, κατηγορίας, χορήγηση άδειας, εμπορίας...
# 2  [εκπαίδευσης, εκπαιδευτικών, δευτεροβάθμιας, δ...
#
#                                  Representative_Docs
# 0  [Συγκρότηση εκλεκτορικών σωμάτων επιλογής και ...
# 1  [Τροποποίηση ως προς την επωνυμία του κατόχου ...
# 2  [Διαβίβαση των αιτήσεων απόσπασης εκπαιδευτικώ...

# %%
freq["Topic"].nunique()
# Out:
# 162

# %% [markdown]
# ##Digital Steps

# %%
digital_steps_topic_model, digital_steps_topics, digital_steps_probs = create_topic_model(15, 8, 0.1, 8, process_digtial_steps_docs)
freq = digital_steps_topic_model.get_topic_info(); freq.head(3)
# Out:
#    Topic  Count                                               Name  \
# 0     -1    274        -1_υποβολής_αρχής_otp_αρχής δημοσίων εσόδων
# 1      0     69  0_ταυτοποίηση χρήστη_ταυτοποίηση_χρήστη ταυτοπ...
# 2      1     40  1_καταγραφή_συμπλήρωση αίτησης_καταγραφή αίτησ...
#
#                                       Representation  \
# 0  [υποβολής, αρχής, otp, αρχής δημοσίων εσόδων, ...
# 1  [ταυτοποίηση χρήστη, ταυτοποίηση, χρήστη ταυτο...
# 2  [καταγραφή, συμπλήρωση αίτησης, καταγραφή αίτη...
#
#                                  Representative_Docs
# 0  [Είσοδος στο διαδικτυακό τόπο της Ανεξάρτητης ...
# 1  [Ταυτοποίηση Χρήστη, Ταυτοποίηση Χρήστη, Ταυτο...
# 2  [Καταγραφή της αίτησης - Έκδοση Βεβαίωσης, Κατ...

# %%
freq["Topic"].nunique()
# Out:
# 80

# %%
digital_steps_topic_model.visualize_hierarchy(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3d263cbb-2235-48d1-9cb3-a57ce3b22f91" class="plotly-graph-div" style="height:950px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d263cbb-2235-48d1-9cb3-a57ce3b22f91")) {                    Plotly.newPlot(                        "3d263cbb-2235-48d1-9cb3-a57ce3b22f91",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8814483851338129,0.8814483851338129,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7819036160634492,0.7819036160634492,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8814483851338129,1.049987117914261,1.049987117914261,0.7819036160634492],"xaxis":"x","y":[-10.0,-10.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9037475685500804,0.9037475685500804,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9165267327330595,0.9165267327330595,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.9165267327330595,0.9660271322239646,0.9660271322239646,0.0],"xaxis":"x","y":[-70.0,-70.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9037475685500804,1.0522573725633766,1.0522573725633766,0.9660271322239646],"xaxis":"x","y":[-50.0,-50.0,-77.5,-77.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9123388148932253,0.9123388148932253,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9275203175888075,0.9275203175888075,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9628200890613698,0.9628200890613698,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9989064407780012,0.9989064407780012,0.9628200890613698],"xaxis":"x","y":[-135.0,-135.0,-150.0,-150.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9862078242775087,0.9862078242775087,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9956533302846726,0.9956533302846726,0.9862078242775087],"xaxis":"x","y":[-165.0,-165.0,-180.0,-180.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9785522625485435,0.9785522625485435,0.0],"xaxis":"x","y":[-195.0,-195.0,-205.0,-205.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0,1.0,0.0],"xaxis":"x","y":[-215.0,-215.0,-225.0,-225.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9785522625485435,1.0028234658992976,1.0028234658992976,1.0],"xaxis":"x","y":[-200.0,-200.0,-220.0,-220.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9956533302846726,1.0111328584457706,1.0111328584457706,1.0028234658992976],"xaxis":"x","y":[-172.5,-172.5,-210.0,-210.0],"yaxis" ...

# %% [markdown]
# No need of further processing

# %% [markdown]
# ## Process Title

# %%
process_title_topic_model, process_title_topics, process_title_probs = create_topic_model(15, 8, 0.1, 8, process_title_docs)
freq = process_title_topic_model.get_topic_info(); freq.head(3)
# Out:
#    Topic  Count                                    Name  \
# 0     -1    703         -1_λειτουργίας_μτν_έγκριση_λόγω
# 1      0    199          0_ναυτικού_πλοίου_πλοίων_πλοία
# 2      1    143  1_απόφασης_βεβαίωση_δικαστικών_ενδίκου
#
#                                       Representation  \
# 0  [λειτουργίας, μτν, έγκριση, λόγω, αναγγελία, π...
# 1  [ναυτικού, πλοίου, πλοίων, πλοία, σκαφών, σκάφ...
# 2  [απόφασης, βεβαίωση, δικαστικών, ενδίκου, πιστ...
#
#                                  Representative_Docs
# 0  [Άδεια εμπορίας πετρελαιοειδών προϊόντων για τ...
# 1  [Πρόσληψη έκτακτου εκπαιδευτικού προσωπικού στ...
# 2  [Βεβαίωση συζήτησης ή μη ενδίκου μέσου (αίτηση...

# %%
freq["Topic"].nunique()
# Out:
# 70

# %% [markdown]
# -1 refers to all outliers. But this amount is quite high, so we would like to reduce the noise. Closely related items will be assigned in the same topic. And in that topic they would be recognised as unique in the similarity process

# %%
reduce_outliers(process_title_docs, process_title_topic_model, process_title_topics, 0.7)
freq = process_title_topic_model.get_topic_info(); freq.head(1)
# Out:
#    Topic  Count                                       Name  \
# 0     -1    395  -1_λόγω_ταυτότητας_πιστοποιητικό_οδήγησης
#
#                                       Representation  \
# 0  [λόγω, ταυτότητας, πιστοποιητικό, οδήγησης, λε...
#
#                                  Representative_Docs
# 0  [Άδεια εμπορίας πετρελαιοειδών προϊόντων για τ...

# %%
digital_steps_topic_model.visualize_hierarchy(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fa5246e0-1348-4ce0-acc1-069228172b7e" class="plotly-graph-div" style="height:950px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa5246e0-1348-4ce0-acc1-069228172b7e")) {                    Plotly.newPlot(                        "fa5246e0-1348-4ce0-acc1-069228172b7e",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8814483851338129,0.8814483851338129,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.7819036160634492,0.7819036160634492,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8814483851338129,1.049987117914261,1.049987117914261,0.7819036160634492],"xaxis":"x","y":[-10.0,-10.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9037475685500804,0.9037475685500804,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.9165267327330595,0.9165267327330595,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.9165267327330595,0.9660271322239646,0.9660271322239646,0.0],"xaxis":"x","y":[-70.0,-70.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9037475685500804,1.0522573725633766,1.0522573725633766,0.9660271322239646],"xaxis":"x","y":[-50.0,-50.0,-77.5,-77.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9123388148932253,0.9123388148932253,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.9275203175888075,0.9275203175888075,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9628200890613698,0.9628200890613698,0.0],"xaxis":"x","y":[-145.0,-145.0,-155.0,-155.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9989064407780012,0.9989064407780012,0.9628200890613698],"xaxis":"x","y":[-135.0,-135.0,-150.0,-150.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9862078242775087,0.9862078242775087,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9956533302846726,0.9956533302846726,0.9862078242775087],"xaxis":"x","y":[-165.0,-165.0,-180.0,-180.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9785522625485435,0.9785522625485435,0.0],"xaxis":"x","y":[-195.0,-195.0,-205.0,-205.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.0,1.0,0.0],"xaxis":"x","y":[-215.0,-215.0,-225.0,-225.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9785522625485435,1.0028234658992976,1.0028234658992976,1.0],"xaxis":"x","y":[-200.0,-200.0,-220.0,-220.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9956533302846726,1.0111328584457706,1.0111328584457706,1.0028234658992976],"xaxis":"x","y":[-172.5,-172.5,-210.0,-210.0],"yaxis" ...

# %%
freq["Topic"].nunique()
# Out:
# 70

# %% [markdown]
# ## Evidences

# %%
process_evidences_topic_model, process_evidences_topics, process_evidences_title_probs = create_topic_model(100, 10, 0.5, 25, process_evidences_docs)
freq = process_evidences_topic_model.get_topic_info(); freq.head(3)
# Out:
#    Topic  Count                                Name  \
# 0     -1   7203     -1_ότι_βεβαίωση_δήλωση_υπεύθυνη
# 1      0    550  0_σπουδών_τίτλου_αλλοδαπής_πτυχίου
# 2      1    413     1_πλοίου_σκάφους_ναυτικού_πλοίο
#
#                                       Representation  \
# 0  [ότι, βεβαίωση, δήλωση, υπεύθυνη, οποία, υπεύθ...
# 1  [σπουδών, τίτλου, αλλοδαπής, πτυχίου, τίτλου σ...
# 2  [πλοίου, σκάφους, ναυτικού, πλοίο, εθνικότητας...
#
#                                  Representative_Docs
# 0  [Υπεύθυνη Δήλωση, Υπεύθυνη δήλωση του νόμου 15...
# 1  [Πράξη ισοτιμίας τίτλου σπουδών της αλλοδαπής ...
# 2  [Έγγραφο Εθνικότητας του πλοίου, Έγγραφο Εθνικ...

# %%
freq["Topic"].nunique()
# Out:
# 78

# %% [markdown]
# -1 refers to all outliers. But this amount is quite high, so we would like to reduce the noise. Closely related items will be assigned in the same topic. And in that topic they would be recognised as unique in the similarity process

# %%
reduce_outliers(process_evidences_docs, process_evidences_topic_model, process_evidences_topics, 0.6)
freq = process_evidences_topic_model.get_topic_info(); freq.head(1)
# Out:
#    Topic  Count                                  Name  \
# 0     -1    866  -1_πιστοποιητικό_οποία_βεβαίωση_κάθε
#
#                                       Representation  \
# 0  [πιστοποιητικό, οποία, βεβαίωση, κάθε, 000, ηχ...
#
#                                  Representative_Docs
# 0  [Υπεύθυνη Δήλωση, Υπεύθυνη δήλωση του νόμου 15...

# %%
process_evidences_topic_model.visualize_hierarchy(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6f2882c0-8343-4200-a801-3258ff9f5757" class="plotly-graph-div" style="height:950px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f2882c0-8343-4200-a801-3258ff9f5757")) {                    Plotly.newPlot(                        "6f2882c0-8343-4200-a801-3258ff9f5757",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5476278484736157,0.5476278484736157,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.5476278484736157,0.7713066106881187,0.7713066106881187,0.0],"xaxis":"x","y":[-20.0,-20.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9902986539675538,0.9902986539675538,0.7713066106881187],"xaxis":"x","y":[-5.0,-5.0,-27.5,-27.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.721060872192717,0.721060872192717,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.721060872192717,0.9633070054946197,0.9633070054946197,0.0],"xaxis":"x","y":[-50.0,-50.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.8552813488952662,0.8552813488952662,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9633070054946197,1.1242257818859451,1.1242257818859451,0.8552813488952662],"xaxis":"x","y":[-57.5,-57.5,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.7263729893030989,0.7263729893030989,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.8722980910497171,0.8722980910497171,0.7263729893030989],"xaxis":"x","y":[-95.0,-95.0,-110.0,-110.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9478536238203285,0.9478536238203285,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9642574692613437,0.9642574692613437,0.9478536238203285],"xaxis":"x","y":[-125.0,-125.0,-140.0,-140.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.7145672502272604,0.7145672502272604,0.0],"xaxis":"x","y":[-165.0,-165.0,-175.0,-175.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.0,0.8919653107121966,0.8919653107121966,0.7145672502272604],"xaxis":"x","y":[-155.0,-155.0,-170.0,-170.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(40,35,35)"},"mode":"lines","x":[0.8919653107121966,0.9281724448776649,0.9281724448776649,0.0],"xaxis":"x","y":[-162.5,-162.5,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9642574692613437,1.008369356739831,1.008369356739831,0.9281724448776649],"xaxis":"x","y":[-132.5,-132.5,-173.75,-173.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9136209061815198,0.9136209061815198,0.0],"xaxis":"x","y":[-195.0,-195.0,-205.0,-205.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9144304752722092,0.9144304752722092,0.0],"xaxis":"x" ...

# %%
topics_to_merge = [[3,7]]
merge_topics (process_evidences_docs, process_evidences_topic_model, topics_to_merge)
# Out:
#    Topic  Count                                               Name  \
# 0     -1    866               -1_πιστοποιητικό_οποία_βεβαίωση_κάθε
# 1      0    766                    0_σπουδών_τίτλου_πτυχίου_σχολής
# 2      1    665  1_ταυτότητας_αστυνομικής ταυτότητας_αστυνομική...
#
#                                       Representation  \
# 0  [πιστοποιητικό, οποία, βεβαίωση, κάθε, 000, ηχ...
# 1  [σπουδών, τίτλου, πτυχίου, σχολής, αλλοδαπής, ...
# 2  [ταυτότητας, αστυνομικής ταυτότητας, αστυνομικ...
#
#                                  Representative_Docs
# 0  [Τα δικαιολογητικά δεν αναφέρονται στην παρούσ...
# 1  [Πράξη ισοτιμίας τίτλου σπουδών της αλλοδαπής ...
# 2  [Φωτοτυπία αστυνομικής ταυτότητας ή διαβατηρίο...

# %%
freq["Topic"].nunique()
# Out:
# 77

# %% [markdown]
# ## Conditions

# %%
process_conditions_topic_model, process_conditions_topics, process_conditions_probs = create_topic_model(15, 8, 0.1, 8, process_conditions_docs)
freq = process_conditions_topic_model.get_topic_info(); freq.head(3)
# Out:
#    Topic  Count                                               Name  \
# 0     -1   3055                -1_σύμφωνα_αίτηση_εφόσον_προϋπόθεση
# 1      0    205  0_εκπαιδευτικοί_εκπαίδευσης_διευθυντή_δευτεροβ...
# 2      1    121  1_taxisnet αιτών είναι_κωδικών taxisnet αιτών_...
#
#                                       Representation  \
# 0  [σύμφωνα, αίτηση, εφόσον, προϋπόθεση, οποία, c...
# 1  [εκπαιδευτικοί, εκπαίδευσης, διευθυντή, δευτερ...
# 2  [taxisnet αιτών είναι, κωδικών taxisnet αιτών,...
#
#                                  Representative_Docs
# 0  [Δεν χορηγείται άδεια λειτουργίας αν δεν παρέλ...
# 1  [Να έχει διοριστεί νομίμως, με πράξη του κατά ...
# 2  [Ο αιτών να είναι κάτοχος κωδικών TAXISnet., Ο...

# %%
freq["Topic"].nunique()
# Out:
# 322

# %% [markdown]
# -1 refers to all outliers. But this amount is quite high, so we would like to reduce the noise. Closely related items will be assigned in the same topic. And in that topic they would be recognised as unique in the similarity process

# %%
reduce_outliers(process_conditions_docs, process_conditions_topic_model, process_conditions_topics, 0.6)
freq = process_conditions_topic_model.get_topic_info(); freq.head(1)
# Out:
#    Topic  Count                          Name  \
# 0     -1    254  -1_00_γεγονότα_συσκευή_24 00
#
#                                       Representation  \
# 0  [00, γεγονότα, συσκευή, 24 00, μήνα, ευρώ μήνα...
#
#                                  Representative_Docs
# 0  [Δεν χορηγείται άδεια λειτουργίας αν δεν παρέλ...

# %%
process_conditions_topic_model.visualize_hierarchy(top_n_topics=50)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="217bb036-a17d-475f-99d0-c2b50c6ce007" class="plotly-graph-div" style="height:950px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("217bb036-a17d-475f-99d0-c2b50c6ce007")) {                    Plotly.newPlot(                        "217bb036-a17d-475f-99d0-c2b50c6ce007",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.9364444289360719,0.9364444289360719,0.0],"xaxis":"x","y":[-5.0,-5.0,-15.0,-15.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.8474305879892062,0.8474305879892062,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.9364444289360719,0.9977944916229364,0.9977944916229364,0.8474305879892062],"xaxis":"x","y":[-10.0,-10.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9529714118713698,0.9529714118713698,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.0,0.9802818909277232,0.9802818909277232,0.9529714118713698],"xaxis":"x","y":[-55.0,-55.0,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","x":[0.9802818909277232,0.9966295956988577,0.9966295956988577,0.0],"xaxis":"x","y":[-62.5,-62.5,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9596289970235261,0.9596289970235261,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9802339253691241,0.9802339253691241,0.9596289970235261],"xaxis":"x","y":[-95.0,-95.0,-110.0,-110.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.0,0.9473879358096646,0.9473879358096646,0.0],"xaxis":"x","y":[-125.0,-125.0,-135.0,-135.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.9473879358096646,0.9897660934153794,0.9897660934153794,0.0],"xaxis":"x","y":[-130.0,-130.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","x":[0.9802339253691241,0.9968305557588301,0.9968305557588301,0.9897660934153794],"xaxis":"x","y":[-102.5,-102.5,-137.5,-137.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.9966295956988577,1.0097872146877747,1.0097872146877747,0.9968305557588301],"xaxis":"x","y":[-73.75,-73.75,-120.0,-120.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.014180862265725,1.014180862265725,1.0097872146877747],"xaxis":"x","y":[-45.0,-45.0,-96.875,-96.875],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(133,20,75)"},"mode":"lines","x":[0.0,0.8843589339815308,0.8843589339815308,0.0],"xaxis":"x","y":[-155.0,-155.0,-165.0,-165.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,220,0)"},"mode":"lines","x":[0.0,0.9412621006255214,0.9412621006255214,0.0],"xaxis":"x","y":[-175.0,-175.0,-185.0,-185.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.8843589339815308,1.000333691487747,1.000333691487747,0.9412621006255214],"xaxis":"x","y":[-160.0,-160.0,-180.0,-180.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[1.014180862265725,1 ...

# %% [markdown]
# No merge

# %% [markdown]
# # Save Topics

# %%
def upload_csv_to_target_folder(topic_model, documents, dataframe, process_id, unique_id, name):

  result = topic_model.get_document_info(documents)
  df = dataframe.reset_index(drop=True) #need also to reindex the df

  result[process_id] = df.loc[result.index, process_id]
  if unique_id != "None":
      result[unique_id] = df.loc[result.index, unique_id]

  path = name+".csv"

  result.to_csv(path, index=False)

  url=folder_analysis_url_shrpt+"topics_extraction"
  target_folder = ctx.web.get_folder_by_server_relative_url(url)
  with open(path, "rb") as content_file:
      file_content = content_file.read()
      target_folder.upload_file(os.path.basename(path), file_content).execute_query()

# %%
upload_csv_to_target_folder(steps_topic_model, process_steps_docs, process_steps, "process_id", "ihu_unique_step_id", "step_topics")

# %%
upload_csv_to_target_folder(digital_steps_topic_model, process_digtial_steps_docs, process_digital_steps, "process_id", "ihu_unique_step_digital_id", "steps_digital_topics")

# %%
upload_csv_to_target_folder(process_title_topic_model, process_title_docs, process_title, "id", "None", "process_title_topics")

# %%
upload_csv_to_target_folder(process_evidences_topic_model, process_evidences_docs, process_evidences, "process_id", "ihu_unique_evidence_id", "evidences_topics")

# %%
upload_csv_to_target_folder(process_conditions_topic_model, process_conditions_docs, process_conditions, "process_id", "ihu_unique_condition_id", "conditions_topics")
