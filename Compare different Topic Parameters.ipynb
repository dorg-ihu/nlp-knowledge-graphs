# %% [markdown]
# # Data

# %%
import pandas as pd

# %%
#connect to G-Drive
from google.colab import drive
mount='/content/gdrive'
drive.mount(mount)
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/MyDrive/Colab Notebooks/Topic Modelling"
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Topic Modelling

# %% [markdown]
# ## 525 Topics

# %%
result = pd.read_csv("final_document_full_paraphrase-multilingual-mpnet-base-v2).csv", sep=',')

# %%
result.head()
# Out:
#    Unnamed: 0                                           Document  Topic  \
# 0          14      Έκδοση άδειας μεταφορέα τύπου ΙΙ (ή τύπου 12)     -1
# 1          16  Διαπίστωση της μη πλήρωσης των προϋποθέσεων: Έ...     -1
# 2          19  Διαπίστωση της πλήρωσης των προϋποθέσεων: Εισή...     -1
# 3          20      Έκδοση άδειας μεταφορέα τύπου ΙΙ (ή τύπου 12)     -1
# 4          48  Εξέταση μαθημάτων για πτυχία Ιατρικής ή Οδοντι...     -1
#
#                               Name  \
# 0  -1_αναφοράς_1ο_σχετικά_1ο μέρος
# 1  -1_αναφοράς_1ο_σχετικά_1ο μέρος
# 2  -1_αναφοράς_1ο_σχετικά_1ο μέρος
# 3  -1_αναφοράς_1ο_σχετικά_1ο μέρος
# 4  -1_αναφοράς_1ο_σχετικά_1ο μέρος
#
#                                       Representation  \
# 0  ['αναφοράς', '1ο', 'σχετικά', '1ο μέρος', 'ως'...
# 1  ['αναφοράς', '1ο', 'σχετικά', '1ο μέρος', 'ως'...
# 2  ['αναφοράς', '1ο', 'σχετικά', '1ο μέρος', 'ως'...
# 3  ['αναφοράς', '1ο', 'σχετικά', '1ο μέρος', 'ως'...
# ...

# %%
print(result.Topic.nunique())
# Out:
# 526

# %%
print(result.Most_Similar_Sentence.nunique())
# Out:
# 7993

# %% [markdown]
# ## 140 Topics

# %%
result2 = pd.read_csv("final_document_full_paraphrase-multilingual-mpnet-base-v2-strict).csv", sep=',')

# %%
result2.head()
# Out:
#    Unnamed: 0                                           Document  Topic  \
# 0          38                      Αναγνώριση πλασματικού χρόνου     -1
# 1          48  Εξέταση μαθημάτων για πτυχία Ιατρικής ή Οδοντι...     -1
# 2          55                              Μη εγγραφή στο μητρώο     -1
# 3          57             Έκδοση καρτέλας  αμπελουργικού μητρώου     -1
# 4          66  Επιλογή έκδοσης Βεβαίωσης ανεργίας για παροχή ...     -1
#
#                             Name  \
# 0  -1_εγγραφή_επιτροπή_προς_μέσω
# 1  -1_εγγραφή_επιτροπή_προς_μέσω
# 2  -1_εγγραφή_επιτροπή_προς_μέσω
# 3  -1_εγγραφή_επιτροπή_προς_μέσω
# 4  -1_εγγραφή_επιτροπή_προς_μέσω
#
#                                       Representation  \
# 0  ['εγγραφή', 'επιτροπή', 'προς', 'μέσω', 'υπηρε...
# 1  ['εγγραφή', 'επιτροπή', 'προς', 'μέσω', 'υπηρε...
# 2  ['εγγραφή', 'επιτροπή', 'προς', 'μέσω', 'υπηρε...
# 3  ['εγγραφή', 'επιτροπή', 'προς', 'μέσω', 'υπηρε...
# 4  ['εγγραφή', 'επιτροπή', 'προς', 'μέσω', 'υπηρε...
#
# ...

# %%
print(result2.Topic.nunique())
# Out:
# 140

# %%
print(result2.Most_Similar_Sentence.nunique())
# Out:
# 5899

# %%
values_not_in_strict = set(result['Most_Similar_Sentence']) - set(result2['Most_Similar_Sentence'])
print(values_not_in_strict)
# Out:
# {'Καταχώριση της διόρθωσης στη ληξιαρχική πράξη γέννησης', 'Διεκπεραίωση του σχεδίου απόφασης', 'Υπογραφή ΕΣΛ', 'Παραλαβή αίτησης για τροποποίηση ως προς την επωνυμία του προμηθευτικού συνεταιρισμού ή της κοινοπραξίας άδειας για προμήθεια πετρελαιοειδών προϊόντων απευθείας από Διυλιστήρια ή από εισαγωγή', 'Επεξεργασία αίτησης και σύνταξη απόφασης παραίτησης', 'Τροποποίηση ως προς τις εγκαταστάσεις Άδειας Εμπορίας Κατηγορίας Γ', 'Πληρωμή Εφάπαξ Βοηθήματος', 'Πρωτοκόλληση της αίτησης και αποστολή φακέλου στο Αρμόδιο Τμήμα', 'Επίδοση απόφασης αυτοπροσώπως κατά την προσέλευση του αιτούντος για ανανέωση του δελτίου αιτούντος διεθνή προστασία', 'Κατάθεση του προσχεδίου προϋπολογισμού της Περιφέρειας στην οικεία Οικονομική Επιτροπή', 'Ενημέρωση για την παραλαβή της άδειας', 'Παραλαβή ένστασης κατά Διοικητικής Απόφασης', 'Κοινοποίηση της δημοσιευμένης στο ΦΕΚ και αναρτημένης στη Διαύγεια Υπουργικής Απόφασης με θέμα: Σύσταση Περιφερειακού Επιμελητηριακού Συμβουλίου Περιφέρειας (συγκεκριμένη Π
# ...
